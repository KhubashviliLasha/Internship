# %% [markdown]
# # combine household appliances by type

# %%
import pandas as pd

# Read the column titles dataframe
file_path = r'D:\Grenoble_university\6_month_internship\working space\flexibility indicators\column_titles.xlsx'
column_titles = pd.read_excel(file_path)

# Define a dictionary to store the flexibility values for each appliance
flexibility_mapping = {}

# Iterate over appliance names
for appliance in column_titles['Names of household appliances']:
    # Split the appliance name into words
    words = appliance.split(' ')
    
    # Check if the appliance name has more than one word
    if len(words) > 4:
        # Join the first two words as the prefix
        prefix = ' '.join(words[:4])
    else:
        # Consider the first word as the prefix
        prefix = words[0]
        
    # If the last character of the prefix is '(', remove it
    if prefix[-1] == '(':
        prefix = prefix[:-1]
    
    # Check if there are parentheses in the prefix
    if '(' in prefix:
        # Remove anything after the last occurrence of parentheses
        prefix = prefix[:prefix.rfind('(')]
    if 'numbers' in prefix:
        prefix= prefix[:prefix.rfind(numbers)]
    
    # Check if the prefix is already in the flexibility_mapping dictionary
    if prefix not in flexibility_mapping:
        # If not, add it with the flexibility value
        flexibility_mapping[prefix] = column_titles.loc[column_titles['Names of household appliances'] == appliance, 'Flexibility'].iloc[0]

# Convert flexibility_mapping dictionary to DataFrame
flexibility_df = pd.DataFrame.from_dict(flexibility_mapping, orient='index', columns=['Flexibility'])

# Reset index to make the prefixes a regular column
flexibility_df.reset_index(inplace=True)
flexibility_df.rename(columns={'index': 'Appliance'}, inplace=True)

# Display the DataFrame
print(flexibility_df)
# Out:
#                        Appliance   Flexibility
# 0                   Dish washer       flexible
# 1                          Chest  not_flexible
# 2                         Fridge  not_flexible
# 3                       Vertical  not_flexible
# 4                       Electric      flexible
# 5               Electric Cooker       flexible
# 6                      Microwave      flexible
# 7                             TV      flexible
# 8                            Hot      flexible
# 9                        Halogen  not_flexible
# 10                       Washing      flexible
# 11                Clothes drier       flexible
# 12                         Water      flexible
# 13            Non halogen lamp 1  not_flexible
# 14                      Aquarium  not_flexible
# 15         Power supply for fuel      flexible
# 16                      Computer      flexible
# 17         Power supply for wood      flexible
# 18                          Heat  not_flexible
# 19            Non halogen lamp 4  not_flexible
# 20                          Site      flexible
# 21          Power supply for gas      flexible
# 22        Heat pump water heater      flexible
# 23            Non halogen lamp 3  not_flexible
# 24         Power supply for wall      flexible
# 25                      No-frost  not_flexible
# 26             Vertical freezer   not_flexible
# 27  Total site light consumption  not_flexible
# 28            Non halogen lamp 2  not_flexible
# 29                    Hot plate       flexible

# %%
import pandas as pd

# Read the column titles dataframe
file_path = r'D:\Grenoble_university\6_month_internship\working space\flexibility indicators\column_titles.xlsx'
column_titles = pd.read_excel(file_path)

# Define a dictionary to store the flexibility values for each appliance
flexibility_mapping = {}

# Iterate over appliance names
for appliance in column_titles['Names of household appliances']:
    # Split the appliance name into words
    words = appliance.split(' ')
    
    # Check if the appliance name has more than one word
    if len(words) > 4:
        # Join the first two words as the prefix
        prefix = ' '.join(words[:4])
    else:
        # Consider the first word as the prefix
        prefix = words[0]
        
    # If the last character of the prefix is '(', remove it
    if prefix[-1] == '(':
        prefix = prefix[:-1]
    
    # Check if there are parentheses in the prefix
    if '(' in prefix:
        # Remove anything after the last occurrence of parentheses
        prefix = prefix[:prefix.rfind('(')]
    
    # Check if there are any numbers in the prefix
    if any(char.isdigit() for char in prefix):
        prefix = prefix[:prefix.rfind(' ')]
    
    # Check if the prefix is already in the flexibility_mapping dictionary
    if prefix not in flexibility_mapping:
        # If not, add it with the flexibility value
        flexibility_mapping[prefix] = column_titles.loc[column_titles['Names of household appliances'] == appliance, 'Flexibility'].iloc[0]

# Convert flexibility_mapping dictionary to DataFrame
flexibility_df = pd.DataFrame.from_dict(flexibility_mapping, orient='index', columns=['Flexibility'])

# Reset index to make the prefixes a regular column
flexibility_df.reset_index(inplace=True)
flexibility_df.rename(columns={'index': 'Appliance'}, inplace=True)

# Display the DataFrame
print(flexibility_df)
# Out:
#                        Appliance   Flexibility
# 0                   Dish washer       flexible
# 1                          Chest  not_flexible
# 2                         Fridge  not_flexible
# 3                       Vertical  not_flexible
# 4                       Electric      flexible
# 5               Electric Cooker       flexible
# 6                      Microwave      flexible
# 7                             TV      flexible
# 8                            Hot      flexible
# 9                        Halogen  not_flexible
# 10                       Washing      flexible
# 11                Clothes drier       flexible
# 12                         Water      flexible
# 13              Non halogen lamp  not_flexible
# 14                      Aquarium  not_flexible
# 15         Power supply for fuel      flexible
# 16                      Computer      flexible
# 17         Power supply for wood      flexible
# 18                          Heat  not_flexible
# 19                          Site      flexible
# 20          Power supply for gas      flexible
# 21        Heat pump water heater      flexible
# 22         Power supply for wall      flexible
# 23                      No-frost  not_flexible
# 24             Vertical freezer   not_flexible
# 25  Total site light consumption  not_flexible
# 26                    Hot plate       flexible

# %%
import pandas as pd

# Read the column titles dataframe
file_path = r'D:\Grenoble_university\6_month_internship\working space\flexibility indicators\column_titles.xlsx'
column_titles = pd.read_excel(file_path)

# Define a dictionary to store the flexibility values for each appliance
flexibility_mapping = {}

# Iterate over appliance names
for appliance in column_titles['Names of household appliances']:
    # Split the appliance name into words
    words = appliance.split(' ')
    
    # Check if the appliance name has more than one word
    if len(words) > 4:
        # Join the first two words as the prefix
        prefix = ' '.join(words[:4])
    else:
        # Consider the first word as the prefix
        prefix = words[0]
        
    # If the last character of the prefix is '(', remove it
    if prefix[-1] == '(':
        prefix = prefix[:-1]
    
    # Check if there are parentheses in the prefix
    if '(' in prefix:
        # Remove anything after the last occurrence of parentheses
        prefix = prefix[:prefix.rfind('(')]
    
    # Check if there are any numbers in the prefix
    if any(char.isdigit() for char in prefix):
        prefix = prefix[:prefix.rfind(' ')]
    
    # If the prefix is empty, use the entire appliance name as the prefix
    if not prefix.strip():
        prefix = appliance
    
    # Check if the prefix is already in the flexibility_mapping dictionary
    if prefix not in flexibility_mapping:
        # If not, add it with the flexibility value
        flexibility_mapping[prefix] = column_titles.loc[column_titles['Names of household appliances'] == appliance, 'Flexibility'].iloc[0]

# Convert flexibility_mapping dictionary to DataFrame
flexibility_df = pd.DataFrame.from_dict(flexibility_mapping, orient='index', columns=['Flexibility'])

# Reset index to make the prefixes a regular column
flexibility_df.reset_index(inplace=True)
flexibility_df.rename(columns={'index': 'Appliance'}, inplace=True)

# Display the DataFrame
print(flexibility_df)
# Out:
#                        Appliance   Flexibility
# 0                   Dish washer       flexible
# 1                          Chest  not_flexible
# 2                         Fridge  not_flexible
# 3                       Vertical  not_flexible
# 4                       Electric      flexible
# 5               Electric Cooker       flexible
# 6                      Microwave      flexible
# 7                             TV      flexible
# 8                            Hot      flexible
# 9                        Halogen  not_flexible
# 10                       Washing      flexible
# 11                Clothes drier       flexible
# 12                         Water      flexible
# 13              Non halogen lamp  not_flexible
# 14                      Aquarium  not_flexible
# 15         Power supply for fuel      flexible
# 16                      Computer      flexible
# 17         Power supply for wood      flexible
# 18                          Heat  not_flexible
# 19                          Site      flexible
# 20          Power supply for gas      flexible
# 21        Heat pump water heater      flexible
# 22         Power supply for wall      flexible
# 23                      No-frost  not_flexible
# 24             Vertical freezer   not_flexible
# 25  Total site light consumption  not_flexible
# 26                    Hot plate       flexible

# %% [markdown]
# # final one

# %%
import pandas as pd

# Read the column titles dataframe
file_path = r'D:\Grenoble_university\6_month_internship\working space\flexibility indicators\column_titles.xlsx'
column_titles = pd.read_excel(file_path)

# Define a dictionary to store the flexibility values for each appliance
flexibility_mapping = {}

# Iterate over appliance names
for appliance in column_titles['Names of household appliances']:
    # Split the appliance name into words
    words = appliance.split(' ')
    
    # Check if the appliance name has more than one word
    if len(words) > 1:
        # Join the first two words as the prefix
        prefix = ' '.join(words[:5])
    else:
        # Consider the first word as the prefix
        prefix = words[0]
        
    # If the last character of the prefix is '(', remove it
    #if prefix[-1] == '(':
    #    prefix = prefix[:-1]
    
    # Check if there are parentheses in the prefix
    if '(' in prefix:
        # Remove anything after the last occurrence of parentheses
        prefix = prefix[:prefix.rfind('(')]
    if '1' in prefix:
        # Remove anything after the last occurrence of 1 
        prefix = prefix[:prefix.rfind('1')]
    if '2' in prefix:
        # Remove anything after the last occurrence of 2
        prefix = prefix[:prefix.rfind('2')]
    if '3' in prefix:
        # Remove anything after the last occurrence of 3
        prefix = prefix[:prefix.rfind('3')]
    if '4' in prefix:
        # Remove anything after the last occurrence of 4
        prefix = prefix[:prefix.rfind('4')]
    if '5' in prefix:
        # Remove anything after the last occurrence of 5
        prefix = prefix[:prefix.rfind('5')]
    # Check if there are parentheses in the prefix
    if '(' in prefix:
        # Remove anything after the last occurrence of parentheses
        prefix = prefix[:prefix.rfind('(')]
    
    # Check if there are any numbers in the prefix
    if any(char.isdigit() for char in prefix):
        prefix = prefix[:prefix.rfind(' ')]
    
    # If the prefix is empty, use the entire appliance name as the prefix
    if not prefix.strip():
        prefix = appliance
    
    # Check if the prefix is already in the flexibility_mapping dictionary
    if prefix not in flexibility_mapping:
        # If not, add it with the flexibility value
        flexibility_mapping[prefix] = column_titles.loc[column_titles['Names of household appliances'] == appliance, 'Flexibility'].iloc[0]

# Convert flexibility_mapping dictionary to DataFrame
flexibility_df = pd.DataFrame.from_dict(flexibility_mapping, orient='index', columns=['Flexibility'])

# Reset index to make the prefixes a regular column
flexibility_df.reset_index(inplace=True)
flexibility_df.rename(columns={'index': 'Appliance'}, inplace=True)

# Display the DataFrame
print(flexibility_df)
# Out:
#                          Appliance   Flexibility
# 0                     Dish washer       flexible
# 1                   Chest freezer   not_flexible
# 2                  Fridge freezer   not_flexible
# 3                Vertical freezer   not_flexible
# 4                   Electric oven       flexible
# 5                 Electric Cooker       flexible
# 6                  Microwave oven       flexible
# 7                              TV       flexible
# 8                       Hot plate       flexible
# 9                          Fridge   not_flexible
# 10                   Halogen lamp   not_flexible
# 11                Washing machine       flexible
# 12                  Clothes drier       flexible
# 13               Electric heating   not_flexible
# 14                   Water heater       flexible
# 15               Non halogen lamp   not_flexible
# 16                       Aquarium   not_flexible
# 17    Power supply for fuel boiler      flexible
# 18                  Computer site       flexible
# 19    Power supply for wood boiler      flexible
# 20                      Heat pump   not_flexible
# 21                     Water pump       flexible
# 22               Site consumption       flexible
# 23  Washing machine+clothes drier       flexible
# 24     Power supply for gas boiler      flexible
# 25            Electric deep frier   not_flexible
# 26         Heat pump water heater       flexible
# 27    Power supply for wall boiler      flexible
# 28                No-frost fridge   not_flexible
# 29   Total site light consumption   not_flexible
