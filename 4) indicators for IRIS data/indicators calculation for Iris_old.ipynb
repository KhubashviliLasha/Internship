# %%
import pandas as pd 

df=pd.read_excel(r"D:\Grenoble_university\6_month_internship\working space\modified_combined_data_all_sheets_final.xlsx")
df
# Out:
#        Unnamed: 0        Weekday              date Fridge (Kitchen, 180l)  \
# 0               0  Uncategorized     Uncategorized           not_flexible
# 1               1       Thursday  01/22/1998 13:40                      0
# 2               2       Thursday  01/22/1998 13:50                     11
# 3               3       Thursday  01/22/1998 14:00                      0
# 4               4       Thursday  01/22/1998 14:10                      0
# ...           ...            ...               ...                    ...
# 53977       53977         Monday  02/01/1999 09:40                      0
# 53978       53978         Monday  02/01/1999 09:50                      0
# 53979       53979         Monday  02/01/1999 10:00                      0
# 53980       53980         Monday  02/01/1999 10:10                     13
# 53981       53981         Monday  02/01/1999 10:20                     13
#
#       Halogen lamp 1 (0,5kW) Power supply for wood boiler ()  \
# 0               not_flexible                        flexible
# 1                         12                              20
# 2                          0                              11
# 3                          0                              11
# 4                          0                              10
# ...                      ...                             ...
# 53977                      0                               6
# 53978                      0                               7
# 53979                      0                               6
# 53980                      0                               7
# 53981                      0                               6
#
#       Site consumption () Total site light consumption ()  \
# 0           Uncategorized                   Uncategorized
# 1                     294                              45
# 2                      85                               3
# 3                      58                               0
# 4                     176                               0
# ...                   ...                             ...
# 53977                 202                               9
# 53978                 220                               8
# 53979                 225                               8
# 53980                 188                              10
# 53981                 540                              12
#
#       Vertical freezer (Cellar, 145l) Washing machine () Water heater ()
# 0                        not_flexible           flexible        flexible
# 1                                  38                  0              37
# 2                                  18                  0              37
# 3                                   1                  0              35
# 4                                   0                  0              38
# ...                               ...                ...             ...
# 53977                               4                  0              76
# 53978                              21                  0              81
# 53979                               5                  0              99
# 53980                               0                  0              54
# 53981                               0                  0             438
#
# [53982 rows x 11 columns]

# %% [markdown]
# ## calculate flexible devices total energy

# %%
# Extract flexibility information from the second row
flexibility_row = df.iloc[0, 3:]

# Identify flexible devices based on the flexibility information
flexible_devices = [col for col, flexibility in zip(df.columns[3:], flexibility_row) if flexibility.lower() == 'flexible']

# Filter out the first two rows
df_numeric = df.iloc[1:]

# Calculate the sum of each flexible power
flexible_sum_2000900 = df_numeric[flexible_devices].sum()

# Print the sum of each flexible power
print("Sum of each flexible power:")
print(flexible_sum_2000900)
# Out:
# Sum of each flexible power:
# Power supply for wood boiler ()     362202
# Washing machine ()                  102045
# Water heater ()                    1880856
# dtype: object

# %%
# Calculate the total sum of power consumption for all flexible devices
total_flexible_power_sum = df_numeric[flexible_devices].sum().sum()

# Print the total sum of power consumption for all flexible devices
print("Total sum of power consumption for all flexible devices:", total_flexible_power_sum)
# Out:
# Total sum of power consumption for all flexible devices: 2345103

# %%
# Extract flexibility information from the second row
Not_flexibility_row = df.iloc[0, 3:]

# Identify flexible devices based on the flexibility information
Not_flexible_devices = [col for col, Not_flexibility in zip(df.columns[3:], Not_flexibility_row) if Not_flexibility.lower() == 'not_flexible']

# Filter out the first two rows
df_numeric = df.iloc[1:]

# Calculate the sum of each flexible power
Not_flexible_sum_2000900 = df_numeric[Not_flexible_devices].sum()

# Print the sum of each flexible power
print("Sum of each Not_flexible power:")
print(Not_flexible_sum_2000900)
# Out:
# Sum of each Not_flexible power:
# Fridge (Kitchen, 180l)             262356
# Halogen lamp 1 (0,5kW)              97408
# Vertical freezer (Cellar, 145l)    340305
# dtype: object

# %%
# Calculate the total sum of power consumption for all flexible devices
total_Not_flexible_power_sum = df_numeric[Not_flexible_devices].sum().sum()

# Print the total sum of power consumption for all flexible devices
print("Total sum of power consumption for all Not_flexible devices:", total_flexible_power_sum)
# Out:
# Total sum of power consumption for all Not_flexible devices: 2345103

# %%
print('indicator =', total_flexible_power_sum/(total_flexible_power_sum+total_Not_flexible_power_sum))
# Out:
# indicator = 0.7701052682738446

# %% [markdown]
# # all sheet calculation

# %%
import pandas as pd

# Define the range of sheet names
start_sheet = 2000900
end_sheet = 2000997

# Initialize a dictionary to store the sum of each flexible power for each sheet
flexible_sum_per_sheet = {}

# Iterate through each sheet in the specified range
for sheet_num in range(start_sheet, end_sheet + 1):
    sheet_name = str(sheet_num)
    try:
        # Read the sheet
        df = pd.read_excel("modified_combined_data_all_sheets_final.xlsx", sheet_name=sheet_name)

        # Extract flexibility information from the second row
        flexibility_row = df.iloc[0, 3:]

        # Identify flexible devices based on the flexibility information
        flexible_devices = [col for col, flexibility in zip(df.columns[3:], flexibility_row) if flexibility.lower() == 'flexible']

        # Filter out the first two rows
        df_numeric = df.iloc[1:]

        # Calculate the sum of each flexible power
        flexible_sum = df_numeric[flexible_devices].sum()

        # Store the sum of each flexible power for the current sheet
        flexible_sum_per_sheet[sheet_name] = flexible_sum
    except Exception as e:
        print(f"Error processing sheet {sheet_name}: {e}")

# Print the sum of each flexible power for each sheet
for sheet_name, flexible_sum in flexible_sum_per_sheet.items():
    print(f"Sheet {sheet_name}:")
    print(flexible_sum)
# Out:
# Sheet 2000900:
# Power supply for wood boiler ()     362202
# Washing machine ()                  102045
# Water heater ()                    1880856
# dtype: object
# Sheet 2000901:
# Clothes drier (without condenser) (3,2kW)    750976
# Dish washer (12 place setting)               538046
# Microwave oven (1,25kW)                       80225
# TV (67cm)                                    241830
# Washing machine (4,5kg, 2,2kW)               345230
# dtype: object
# Sheet 2000902:
# Clothes drier (without condenser) ()     607314
# Electric Cooker (hot plate+oven) ()       92119
# Microwave oven ()                         45805
# TV (36cm)                                129304
# Washing machine (5kg,750rpm)             516214
# Water heater ()                         1271954
# dtype: object
# Sheet 2000903:
# Dish washer (12 place setting)     507508
# Power supply for fuel boiler ()    400107
# Washing machine (3,25kW)           214335
# dtype: object
# Sheet 2000904:
# Clothes drier (without condenser) (5kg)     762491
# Electric Cooker (hot plate+oven) ()         264211
# Washing machine (5kg)                       580145
# Water heater ()                            2891100
# dtype: object
# Sheet 2000905:
# Microwave oven (0,7kW)     15792
# TV (36cm)                 106088
# Washing machine ()        165764
# dtype: object
# Sheet 2000906:
# Electric Cooker (hot plate+oven) ()    219655
# Microwave oven (1,2kW)                  89345
# TV (70cm)                              285360
# TV ()                                    2700
# Washing machine (800rpm)               253976
# dtype: object
# Sheet 2000907:
# Clothes drier (without condenser) ()     829906
# Dish washer (12 place setting)           315904
# Microwave oven ()                         26252
# Washing machine ()                       357481
# Water heater ()                         2270696
# dtype: object
# Sheet 2000908:
# Clothes drier (with condenser) ()    274650
# Dish washer (12 place setting)       334493
# Electric oven ()                     113702
# Hot plate (3 gas, 1elec)               1058
# Microwave oven (1,35kW)               74579
# TV (51cm)                            211318
# Washing machine ()                   349791
# dtype: object
# Sheet 2000909:
# Electric Cooker (hot plate+oven) (3 radiant)     657334
# Microwave oven ()                                185569
# TV (78cm)                                        304335
# Washing machine ()                               462426
# Water heater ()                                 2776802
# dtype: object
# Sheet 2000910:
# Dish washer (12 place setting)          70485
# Electric Cooker (hot plate+oven) ()    239270
# Microwave oven (Fonte, 1,35kW)          62224
# TV ()                                  112024
# Washing machine ()                      26014
# dtype: object
# Sheet 2000911:
# Electric Cooker (hot plate+oven) ()    334930
# TV (51cm)                               77091
# Washing machine ()                      74161
# dtype: object
# Sheet 2000912:
# Electric Cooker (hot plate+oven) (1,5kW)    148151
# TV (67cm)                                   201214
# Washing machine ()                          316046
# dtype: object
# Sheet 2000913:
# Microwave oven (1,1kW)              49749
# Power supply for fuel boiler ()    364826
# TV (67cm)                          154444
# Washing machine ()                 226371
# dtype: object
# Sheet 2000914:
# Clothes drier (without condenser) (2,5kW)      22683
# Dish washer (12 place setting)                125767
# Electric Cooker (hot plate+oven) (5,1kW)      375743
# Microwave oven (1,2kW)                         68874
# TV (67cm)                                     167134
# TV (51cm)                                      51111
# Washing machine (2,2kW)                       226541
# Water heater ()                              3160611
# dtype: object
# Sheet 2000915:
# Clothes drier (without condenser) ()     128664
# Electric Cooker (hot plate+oven) ()      758092
# Heat pump water heater ()               2283218
# Microwave oven ()                         91874
# TV ()                                    168779
# TV (63cm)                                121002
# Washing machine ()                       250275
# Water heater ()                           46103
# dtype: object
# Sheet 2000916:
# Dish washer (12 place setting)      519116
# Electric oven (Pyrolysis, 3,1kW)    279169
# Hot plate ()                        195345
# Microwave oven (1,6kW)              252965
# TV (70cm)                           329022
# TV (36cm)                            42762
# TV (36cm).1                          10628
# Washing machine ()                  271670
# dtype: object
# Sheet 2000917:
# Dish washer (12 place setting, 2,3kW)    1181926
# Electric Cooker (hot plate+oven) ()       221464
# Microwave oven ()                          30619
# TV (67cm)                                 271669
# TV (51cm)                                  34193
# Washing machine (5kg, 2,15kW)             490518
# dtype: object
# Sheet 2000918:
# Electric Cooker (hot plate+oven) ()    73978
# Microwave oven (3,4kW)                 23355
# TV ()                                  87249
# Washing machine (2,1kW)                89196
# dtype: object
# Sheet 2000919:
# Electric oven (2,95kW)             2643382
# Microwave oven (1,3kW)              305990
# Power supply for fuel boiler ()     149991
# Washing machine (2,25kW)            459994
# dtype: object
# Sheet 2000920:
# Dish washer (12 place setting)    407438
# Microwave oven (1,3kW)            413053
# TV (51cm)                         409492
# TV (36cm)                         410743
# TV ()                             414101
# Washing machine (500rpm)          417912
# dtype: object
# Sheet 2000921:
# Electric Cooker (hot plate+oven) ()      76281
# Microwave oven ()                       149663
# TV (36cm)                                66082
# TV (36cm).1                             145143
# Washing machine (1,85kW)                143919
# Water heater ()                        3600145
# dtype: object
# Sheet 2000922:
# Dish washer (12 place setting)      436048
# Electric oven (2,1kW)               367477
# Microwave oven (1kW)                 35515
# TV (36cm)                           170655
# TV (70cm)                            96007
# TV (36cm).1                          15881
# Washing machine+clothes drier ()    243227
# dtype: object
# Sheet 2000923:
# Electric Cooker (hot plate+oven) ()    364963
# TV (36cm)                               55767
# Washing machine ()                     165321
# dtype: object
# Sheet 2000924:
# Electric Cooker (hot plate+oven) ()    898928
# Power supply for fuel boiler ()        889288
# TV (51cm)                              829827
# TV (70cm)                              838481
# Washing machine (1,85kW)               885580
# dtype: object
# Sheet 2000925:
# Dish washer (8 place setting)     110789
# Microwave oven ()                  82828
# Microwave oven ().1                38045
# Power supply for gas boiler ()    465033
# Washing machine ()                159514
# dtype: object
# Sheet 2000926:
# Dish washer (12 place setting)    158044
# Electric oven (2,5kW)              36142
# Washing machine ()                167989
# dtype: object
# Sheet 2000927:
# Clothes drier (without condenser) ()    558602
# Electric oven ()                         92118
# Microwave oven (1,1kW)                  145196
# TV (47cm)                               213172
# Washing machine ()                      826743
# dtype: object
# Sheet 2000928:
# Clothes drier (without condenser) ()      69951
# Dish washer (12 place setting)           171668
# Electric Cooker (hot plate+oven) ()       62247
# Microwave oven ()                         14671
# TV (61cm)                                167581
# TV (36cm)                                 14812
# Washing machine ()                       100426
# Water heater ()                         1681942
# dtype: object
# Sheet 2000929:
# Microwave oven (2,5kW)                     6738
# TV (36cm)                                 53663
# Washing machine+clothes drier (2,23kW)    76213
# dtype: object
# Sheet 2000930:
# Clothes drier (without condenser) ()    566223
# Dish washer (12 place setting)          325850
# TV (71cm)                                 9813
# TV (36cm)                               352989
# Washing machine ()                      274654
# dtype: object
# Sheet 2000931:
# Aquarium ()                             1241019
# Clothes drier (without condenser) ()     115884
# Dish washer (12 place setting)           420823
# Electric oven (1,1kW)                     49022
# Microwave oven (1,2kW)                    44715
# Washing machine ()                       283298
# dtype: object
# Sheet 2000932:
# Electric Cooker (hot plate+oven) ()    342941
# Microwave oven (0,95kW)                 59843
# TV (56cm)                               98242
# TV (36cm)                               25449
# Washing machine ()                     157639
# dtype: object
# Sheet 2000933:
# Dish washer (12 place setting)         139871
# Electric Cooker (hot plate+oven) ()    151419
# Microwave oven (0,75kW)                 44975
# TV (51cm)                               98958
# Washing machine ()                     192736
# dtype: object
# Sheet 2000934:
# Clothes drier (without condenser) ()     208614
# Microwave oven ()                         39280
# TV ()                                    474866
# TV ().1                                  190027
# Washing machine ()                       224781
# Water heater ()                         1299844
# dtype: object
# Sheet 2000935:
# Electric oven ()      328991
# TV (36cm)               1200
# TV (36cm).1            38559
# TV (51cm)             279774
# Washing machine ()    252634
# dtype: object
# Sheet 2000936:
# Clothes drier (without condenser) ()     151476
# Dish washer (12 place setting)           139291
# TV (55cm)                                138547
# TV (36cm)                                 11300
# Washing machine ()                       316690
# Water heater ()                         1999892
# dtype: object
# Sheet 2000937:
# Dish washer (12 place setting)    254582
# Electric oven ()                  137768
# Microwave oven ()                  18015
# TV ()                              68968
# TV ().1                            41500
# TV ().2                            92197
# Washing machine ()                206705
# dtype: object
# Sheet 2000938:
# Clothes drier (with condenser) (2,55kW)     328721
# Dish washer (12 place setting, 3,1kW)       219409
# Electric Cooker (hot plate+oven) (6kW)      985801
# TV (60cm)                                   354602
# TV (60cm).1                                  40509
# Washing machine ()                          169063
# Water heater ()                            2351818
# dtype: object
# Sheet 2000939:
# Clothes drier (without condenser) (1,8kW)    183063
# Dish washer (12 place setting)               443989
# Electric oven ()                             410353
# Microwave oven ()                             98062
# Microwave oven ().1                           88280
# Washing machine ()                           319996
# dtype: object
# Sheet 2000940:
# Clothes drier (without condenser) ()    1143857
# Dish washer (12 place setting)           233771
# Power supply for gas boiler ()           118937
# TV (51cm)                                 76736
# Washing machine ()                       227521
# dtype: object
# Sheet 2000941:
# Dish washer (12 place setting)         332356
# Electric Cooker (hot plate+oven) ()    269507
# Microwave oven ()                       36641
# TV (51cm)                              116365
# Washing machine ()                     110489
# dtype: object
# Sheet 2000942:
# Microwave oven (1,35kW)            201007
# Power supply for fuel boiler ()    208817
# TV (65cm)                          540398
# Washing machine ()                 278627
# dtype: object
# Sheet 2000943:
# Clothes drier (without condenser) ()    269345
# Dish washer (12 place setting)          230825
# Electric oven ()                         97806
# Microwave oven ()                        75523
# Power supply for fuel boiler ()         552767
# Washing machine ()                      112278
# dtype: object
# Sheet 2000944:
# Clothes drier (without condenser) ()     258278
# Dish washer (12 place setting)           220666
# Washing machine ()                        50280
# Water heater ()                         1876575
# dtype: object
# Sheet 2000945:
# Electric Cooker (hot plate+oven) ()     556938
# Microwave oven ()                        71633
# TV (70cm)                               435639
# TV (55cm)                                17293
# Washing machine ()                       72944
# Water heater ()                        2069122
# dtype: object
# Sheet 2000946:
# Clothes drier (without condenser) ()    176094
# Dish washer (12 place setting)          205879
# Electric oven ()                        133186
# Hot plate ()                             33519
# Microwave oven ()                       153332
# Washing machine ()                      295118
# dtype: object
# Sheet 2000947:
# Clothes drier (without condenser) ()     811125
# Dish washer (12 place setting, 3,3kW)    524695
# Electric oven ()                         188097
# Hot plate ()                             263514
# Microwave oven ()                         84592
# TV (51cm)                                235401
# TV (36cm)                                 81569
# TV (36cm).1                              167796
# Washing machine ()                       339017
# dtype: object
# Sheet 2000948:
# Dish washer (12 place setting)          104053
# Electric Cooker (hot plate+oven) ()     385274
# Washing machine+clothes drier ()        117206
# Water heater ()                        1851451
# Water pump ()                          1138527
# dtype: object
# Sheet 2000949:
# Dish washer (12 place setting)    183432
# Electric oven ()                   81429
# Microwave oven (1,1kW)             18238
# Power supply for gas boiler ()    665287
# TV ()                             236778
# Washing machine ()                164865
# dtype: object
# Sheet 2000950:
# Dish washer (12 place setting)    1024225
# Microwave oven ()                   32224
# TV ()                              204891
# TV ().1                             15821
# Washing machine ()                 411577
# dtype: object
# Sheet 2000951:
# Electric Cooker (hot plate+oven) ()    270238
# Microwave oven ()                      114653
# Washing machine ()                     156395
# dtype: object
# Sheet 2000952:
# Clothes drier (without condenser) ()    114599
# Dish washer (12 place setting)          235266
# Electric oven ()                        104022
# Microwave oven (1,5kW)                   85285
# Power supply for fuel boiler ()         299255
# TV (70cm)                               116214
# TV (55cm)                                75712
# TV (36cm)                                96924
# Washing machine ()                      316965
# dtype: object
# Sheet 2000953:
# Dish washer (12 place setting)     154580
# TV (63cm)                          187819
# TV (36cm)                            6239
# Washing machine ()                 110694
# Water heater ()                   1891735
# dtype: object
# Sheet 2000954:
# TV (70cm)              242496
# TV (36cm)               24491
# Washing machine ()     104464
# Water heater ()       3286960
# dtype: object
# Sheet 2000955:
# Electric oven ()       310174
# TV (36cm)               25473
# Washing machine ()     110684
# Water heater ()       2332300
# dtype: object
# Sheet 2000956:
# Electric oven ()       113892
# Microwave oven ()       48126
# TV ()                  164657
# TV ().1                 27418
# Washing machine ()     272700
# Water heater ()       1528081
# dtype: object
# Sheet 2000957:
# Microwave oven (1,45kW)     38834
# TV (63cm)                   40844
# Washing machine ()         216366
# dtype: object
# Sheet 2000958:
# Microwave oven (1,3kW)     26240
# TV (63cm)                 136604
# TV (36cm)                   9172
# Washing machine ()        148822
# dtype: object
# Sheet 2000959:
# Clothes drier (without condenser) ()     341253
# Microwave oven (0,9kW)                    57071
# TV (60cm)                                202481
# Washing machine ()                       297659
# Water heater ()                         2253071
# dtype: object
# Sheet 2000960:
# Clothes drier (with condenser) ()    559570
# Microwave oven ()                     37461
# TV (55cm)                            139368
# TV (36cm)                             21553
# Washing machine ()                   276689
# dtype: object
# Sheet 2000961:
# Dish washer (12 place setting)    310529
# Washing machine ()                153429
# dtype: object
# Sheet 2000962:
# Clothes drier (without condenser) ()     980319
# Microwave oven ()                         58172
# TV ()                                    299342
# TV ().1                                   10795
# Washing machine ()                       365211
# Water heater ()                         3019609
# dtype: object
# Sheet 2000963:
# TV (36cm)             101015
# Washing machine ()     20046
# dtype: object
# Sheet 2000964:
# Dish washer (12 place setting)                      538158
# Electric Cooker (hot plate+oven) (1 elec, 3 gas)    134219
# Microwave oven ()                                    69765
# TV (55cm)                                           173765
# TV (36cm)                                            31258
# Washing machine ()                                  307365
# dtype: object
# Sheet 2000965:
# Clothes drier (without condenser) ()    172348
# Washing machine ()                      161787
# dtype: object
# Sheet 2000966:
# Clothes drier (without condenser) ()    844718
# Dish washer (12 place setting)          357843
# Electric oven (2,58kW)                  117164
# TV ()                                    75890
# TV ().1                                   9937
# Washing machine (2kW)                   236681
# dtype: object
# Sheet 2000967:
# Hot plate (ceramic hobs)     150040
# Microwave oven (1,25kW)       20242
# Microwave oven (1,7kW)       120889
# TV (33cm)                     93680
# Washing machine ()            81540
# Water heater ()             1802873
# dtype: object
# Sheet 2000968:
# Electric Cooker (hot plate+oven) (3,3kW)      91311
# TV (33cm)                                     75005
# Washing machine+clothes drier ()             156847
# Water heater (100l)                         1143230
# dtype: object
# Sheet 2000969:
# Dish washer (6 place setting)        18124
# Microwave oven ()                    26386
# TV ()                                26799
# Washing machine+clothes drier ()    152202
# dtype: object
# Sheet 2000970:
# Clothes drier (with condenser) ()        131869
# Dish washer (12 place setting, 3,2kW)    185613
# Electric oven (3,5kW)                    331137
# TV (55cm)                                118729
# TV (36cm)                                 42266
# dtype: object
# Sheet 2000971:
# Computer site ()                   759210
# Microwave oven ()                  157807
# Power supply for fuel boiler ()    503177
# TV ()                              165095
# Washing machine ()                 314241
# dtype: object
# Sheet 2000972:
# Clothes drier (with condenser) ()      453300
# Dish washer (12 place setting)         282437
# Electric Cooker (hot plate+oven) ()    204627
# TV (68cm)                              235553
# TV ()                                   15728
# Washing machine ()                     119366
# dtype: object
# Sheet 2000973:
# Electric oven ()      299855
# Microwave oven ()      29338
# TV ()                  27355
# Washing machine ()    292742
# dtype: object
# Sheet 2000974:
# Dish washer (12 place setting)       235957
# Electric oven ()                      74902
# Hot plate ()                         245271
# TV (70cm)                            330604
# TV (35cm)                             17638
# TV ()                                  4846
# Washing machine+clothes drier ()      84319
# Water heater ()                     2437400
# dtype: object
# Sheet 2000975:
# Hot plate ()               0
# Microwave oven ()      28915
# TV ()                  37549
# Washing machine ()     49177
# Water heater ()       745546
# dtype: object
# Sheet 2000976:
# Microwave oven (1,1kW)     53114
# TV (36cm)                  94398
# TV (36cm).1                40738
# Washing machine ()        392920
# dtype: object
# Sheet 2000977:
# Microwave oven (0,65kW)      69570
# TV (35cm)                   105214
# Water heater ()            1225115
# dtype: object
# Sheet 2000978:
# Clothes drier (with condenser) ()     379404
# Electric oven (3,14kW)                209061
# TV ()                                 248176
# TV (33cm)                              19991
# Washing machine ()                    324172
# Water heater ()                      5681254
# dtype: object
# Sheet 2000979:
# Dish washer (12 place setting)     178640
# Electric oven (2,6kW)              213193
# Microwave oven (3,35kW)             28743
# Power supply for wall boiler ()    277247
# TV ()                               23615
# Washing machine ()                 204145
# dtype: object
# Sheet 2000980:
# Dish washer (12 place setting)    451448
# Electric oven ()                  182932
# Hot plate ()                      316251
# Microwave oven ()                  27515
# TV (33cm)                          78837
# TV ()                              19340
# Washing machine ()                158076
# dtype: object
# Sheet 2000981:
# Aquarium ()                        216885
# Dish washer (12 place setting)     370875
# Microwave oven ()                  266695
# TV ()                              116992
# TV ().1                              3577
# Washing machine ()                  37704
# Water heater ()                   2359753
# dtype: object
# Sheet 2000982:
# Electric oven (3,375kW)              181384
# Hot plate (6kW)                      123070
# Microwave oven (1kW)                  50570
# TV ()                                 54925
# Washing machine+clothes drier ()     282834
# Water heater ()                     2391989
# dtype: object
# Sheet 2000983:
# Dish washer (12 place setting)        99370
# Hot plate ()                          77775
# Microwave oven (3,2kW)               100212
# TV (33cm)                             70225
# Washing machine+clothes drier ()      87173
# Water heater ()                     1399170
# Water heater ().1                    151962
# dtype: object
# Sheet 2000984:
# Dish washer (12 place setting)         142992
# Electric Cooker (hot plate+oven) ()    718017
# Microwave oven ()                       12374
# TV (70cm)                              234194
# TV (35cm)                               39229
# Washing machine ()                     177852
# dtype: object
# Sheet 2000985:
# Aquarium (78l)                         353644
# Dish washer (12 place setting)         457059
# Electric Cooker (hot plate+oven) ()    250346
# Microwave oven ()                       34676
# TV (70cm)                              100832
# Washing machine ()                     312439
# dtype: object
# Sheet 2000986:
# Aquarium ()                            258858
# Electric Cooker (hot plate+oven) ()     13798
# Microwave oven ()                       66839
# Microwave oven (1,1kW)                 101664
# TV (55cm)                              145620
# Washing machine ()                     136348
# dtype: object
# Sheet 2000987:
# Aquarium (60l)                           288527
# Clothes drier (without condenser) ()      15049
# Electric Cooker (hot plate+oven) ()      198068
# Microwave oven ()                         37722
# TV (50cm)                                221952
# TV (47cm)                                  5150
# Washing machine ()                       177036
# Water heater (200l)                     2219048
# dtype: object
# Sheet 2000988:
# Microwave oven (1,3kW)    320620
# TV (55cm)                  83017
# Washing machine ()        160526
# dtype: object
# Sheet 2000989:
# Clothes drier (with condenser) ()     564242
# Dish washer (12 place setting)        576276
# Microwave oven (1,65kW)               111127
# Site consumption (Garage, 200l)      5843982
# TV (72cm)                             258050
# TV (36cm)                              18610
# Washing machine ()                    469028
# dtype: object
# Sheet 2000990:
# Computer site ()            322873
# Microwave oven (2,75kW)      72724
# TV (55cm)                    98227
# Washing machine ()          143132
# Water heater ()            1038109
# dtype: object
# Sheet 2000991:
# Dish washer (12 place setting)      80425
# Microwave oven (1,2kW)              43446
# Washing machine ()                 311174
# Water heater ()                   1717903
# dtype: object
# Sheet 2000992:
# Aquarium (28?C, 400l)                786133
# Clothes drier (with condenser) ()     85643
# Microwave oven ()                      6243
# TV (55cm)                            179736
# dtype: object
# Sheet 2000993:
# Dish washer (12 place setting)         92531
# Electric Cooker (hot plate+oven) ()    42456
# Microwave oven (1,98kW)                23064
# Microwave oven ()                       2515
# Power supply for fuel boiler ()        53544
# TV (50cm)                              12380
# Washing machine ()                     79795
# dtype: object
# Sheet 2000994:
# Microwave oven (1,25kW)    22590
# TV (50cm)                  74744
# TV ()                          0
# Washing machine ()         60624
# dtype: object
# Sheet 2000995:
# Microwave oven (1,2kW)    152555
# TV (65cm)                 173848
# TV (24cm)                  22380
# Washing machine ()         93974
# dtype: object
# Sheet 2000996:
# Clothes drier (without condenser) ()     57621
# Dish washer (12 place setting)           68829
# Electric oven ()                        245598
# Microwave oven (1,25kW)                  94550
# TV (70cm)                               304102
# TV (36cm)                                15667
# TV (66cm)                                59749
# Washing machine ()                      278707
# dtype: object
# Sheet 2000997:
# Dish washer (12 place setting)    266502
# Electric oven ()                  339379
# Microwave oven ()                 128726
# TV (65cm)                         186666
# TV (36cm)                          33823
# Washing machine ()                196111
# dtype: object

# %% [markdown]
# # to save as excel file

# %%
# Convert the dictionary into a DataFrame
flexible_sum_df = pd.DataFrame(flexible_sum_per_sheet)

# Save the DataFrame to an Excel file
#flexible_sum_df.to_excel("flexible_sum_per_sheet.xlsx")

# %%
flexible_sum_df
# Out:
#                                    2000900 2000901  2000902 2000903  2000904  \
# Aquarium ()                            NaN     NaN      NaN     NaN      NaN
# Aquarium (28?C, 400l)                  NaN     NaN      NaN     NaN      NaN
# Aquarium (60l)                         NaN     NaN      NaN     NaN      NaN
# Aquarium (78l)                         NaN     NaN      NaN     NaN      NaN
# Clothes drier (with condenser) ()      NaN     NaN      NaN     NaN      NaN
# ...                                    ...     ...      ...     ...      ...
# Water heater ()                    1880856     NaN  1271954     NaN  2891100
# Water heater ().1                      NaN     NaN      NaN     NaN      NaN
# Water heater (100l)                    NaN     NaN      NaN     NaN      NaN
# Water heater (200l)                    NaN     NaN      NaN     NaN      NaN
# Water pump ()                          NaN     NaN      NaN     NaN      NaN
#
#                                   2000905 2000906  2000907 2000908  2000909  \
# Aquarium ()                           NaN     NaN      NaN     NaN      NaN
# Aquarium (28?C, 400l)                 NaN     NaN      NaN     NaN      NaN
# Aquarium (60l)                        NaN     NaN      NaN     NaN      NaN
# Aquarium (78l)                        NaN     NaN      NaN     NaN      NaN
# Clothes drier (with condenser) ()     NaN     NaN      NaN  274650      NaN
# ...                                   ...     ...      ...     ...      ...
# Water heater ()                       NaN     NaN  2270696     NaN  2776802
# Water heater ().1                     NaN     NaN      NaN     NaN      NaN
# Water heater (100l)                   NaN     NaN      NaN     NaN      NaN
# Water heater (200l)                   NaN     NaN      NaN     NaN      NaN
# Water pump ()                         NaN     NaN      NaN     NaN      NaN
#
#                                    ... 2000988 2000989  2000990  2000991  \
# Aquarium ()                        ...     NaN     NaN      NaN      NaN
# Aquarium (28?C, 400l)              ...     NaN     NaN      NaN      NaN
# Aquarium (60l)                     ...     NaN     NaN      NaN      NaN
# Aquarium (78l)                     ...     NaN     NaN      NaN      NaN
# Clothes drier (with condenser) ()  ...     NaN  564242      NaN      NaN
# ...                                ...     ...     ...      ...      ...
# Water heater ()                    ...     NaN     NaN  1038109  1717903
# Water heater ().1                  ...     NaN     NaN      NaN      NaN
# Water heater (100l)                ...     NaN     NaN      NaN      NaN
# Water heater (200l)                ...     NaN     NaN      NaN      NaN
# Water pump ()                      ...     NaN     NaN      NaN      NaN
#
#                                   2000992 2000993 2000994 2000995 2000996  \
# Aquarium ()                           NaN     NaN     NaN     NaN     NaN
# Aquarium (28?C, 400l)              786133     NaN     NaN     NaN     NaN
# Aquarium (60l)                        NaN     NaN     NaN     NaN     NaN
# Aquarium (78l)                        NaN     NaN     NaN     NaN     NaN
# Clothes drier (with condenser) ()   85643     NaN     NaN     NaN     NaN
# ...                                   ...     ...     ...     ...     ...
# Water heater ()                       NaN     NaN     NaN     NaN     NaN
# Water heater ().1                     NaN     NaN     NaN     NaN     NaN
# Water heater (100l)                   NaN     NaN     NaN     NaN     NaN
# Water heater (200l)                   NaN     NaN     NaN     NaN     NaN
# Water pump ()                         NaN     NaN     NaN     NaN     NaN
#
#                                   2000997
# Aquarium ()                           NaN
# Aquarium (28?C, 400l)                 NaN
# Aquarium (60l)                        NaN
# Aquarium (78l)                        NaN
# Clothes drier (with condenser) ()     NaN
# ...                                   ...
# Water heater ()                       NaN
# Water heater ().1                     NaN
# Water heater (100l)                   NaN
# Water heater (200l)                   NaN
# Water pump ()                         NaN
#
# [117 rows x 98 columns]

# %%
# Initialize a dictionary to store the sum of each device across all sheets
total_flexibility_per_device = {}

# Iterate through each sheet
for flexible_sum in flexible_sum_per_sheet.values():
    # Iterate through each device in the current sheet
    for device, value in flexible_sum.items():
        # Add the value to the total for the current device
        total_flexibility_per_device[device] = total_flexibility_per_device.get(device, 0) + value

# Print the sum of flexibility for each device across all sheets
print("Total flexibility sum for each device:")
for device, total_sum in total_flexibility_per_device.items():
    print(f"{device}: {total_sum}")
# Out:
# Total flexibility sum for each device:
# Power supply for wood boiler (): 362202
# Washing machine (): 16073054
# Water heater (): 66139779
# Clothes drier (without condenser) (3,2kW): 750976
# Dish washer (12 place setting): 12743847
# Microwave oven (1,25kW): 217607
# TV (67cm): 1036291
# Washing machine (4,5kg, 2,2kW): 345230
# Clothes drier (without condenser) (): 8421240
# Electric Cooker (hot plate+oven) (): 7009767
# Microwave oven (): 2390511
# TV (36cm): 2043272
# Washing machine (5kg,750rpm): 516214
# Power supply for fuel boiler (): 3421772
# Washing machine (3,25kW): 214335
# Clothes drier (without condenser) (5kg): 762491
# Washing machine (5kg): 580145
# Microwave oven (0,7kW): 15792
# Microwave oven (1,2kW): 398935
# TV (70cm): 3312951
# TV (): 3050665
# Washing machine (800rpm): 253976
# Clothes drier (with condenser) (): 2448678
# Electric oven (): 3254204
# Hot plate (3 gas, 1elec): 1058
# Microwave oven (1,35kW): 275586
# TV (51cm): 2420266
# Electric Cooker (hot plate+oven) (3 radiant): 657334
# TV (78cm): 304335
# Microwave oven (Fonte, 1,35kW): 62224
# Electric Cooker (hot plate+oven) (1,5kW): 148151
# Microwave oven (1,1kW): 367961
# Clothes drier (without condenser) (2,5kW): 22683
# Electric Cooker (hot plate+oven) (5,1kW): 375743
# Washing machine (2,2kW): 226541
# Heat pump water heater (): 2283218
# TV (63cm): 486269
# Electric oven (Pyrolysis, 3,1kW): 279169
# Hot plate (): 1131675
# Microwave oven (1,6kW): 252965
# TV (36cm).1: 418745
# Dish washer (12 place setting, 2,3kW): 1181926
# Washing machine (5kg, 2,15kW): 490518
# Microwave oven (3,4kW): 23355
# Washing machine (2,1kW): 89196
# Electric oven (2,95kW): 2643382
# Microwave oven (1,3kW): 1065903
# Washing machine (2,25kW): 459994
# Washing machine (500rpm): 417912
# Washing machine (1,85kW): 1029499
# Electric oven (2,1kW): 367477
# Microwave oven (1kW): 86085
# Washing machine+clothes drier (): 1123808
# Dish washer (8 place setting): 110789
# Microwave oven ().1: 126325
# Power supply for gas boiler (): 1249257
# Electric oven (2,5kW): 36142
# TV (47cm): 218322
# TV (61cm): 167581
# Microwave oven (2,5kW): 6738
# Washing machine+clothes drier (2,23kW): 76213
# TV (71cm): 9813
# Aquarium (): 1716762
# Electric oven (1,1kW): 49022
# Microwave oven (0,95kW): 59843
# TV (56cm): 98242
# Microwave oven (0,75kW): 44975
# TV ().1: 299075
# TV (55cm): 1170014
# TV ().2: 92197
# Clothes drier (with condenser) (2,55kW): 328721
# Dish washer (12 place setting, 3,1kW): 219409
# Electric Cooker (hot plate+oven) (6kW): 985801
# TV (60cm): 557083
# TV (60cm).1: 40509
# Clothes drier (without condenser) (1,8kW): 183063
# TV (65cm): 900912
# Dish washer (12 place setting, 3,3kW): 524695
# Water pump (): 1138527
# Microwave oven (1,5kW): 85285
# Microwave oven (1,45kW): 38834
# Microwave oven (0,9kW): 57071
# Electric Cooker (hot plate+oven) (1 elec, 3 gas): 134219
# Electric oven (2,58kW): 117164
# Washing machine (2kW): 236681
# Hot plate (ceramic hobs): 150040
# Microwave oven (1,7kW): 120889
# TV (33cm): 337738
# Electric Cooker (hot plate+oven) (3,3kW): 91311
# Water heater (100l): 1143230
# Dish washer (6 place setting): 18124
# Dish washer (12 place setting, 3,2kW): 185613
# Electric oven (3,5kW): 331137
# Computer site (): 1082083
# TV (68cm): 235553
# TV (35cm): 162081
# Microwave oven (0,65kW): 69570
# Electric oven (3,14kW): 209061
# Electric oven (2,6kW): 213193
# Microwave oven (3,35kW): 28743
# Power supply for wall boiler (): 277247
# Electric oven (3,375kW): 181384
# Hot plate (6kW): 123070
# Microwave oven (3,2kW): 100212
# Water heater ().1: 151962
# Aquarium (78l): 353644
# Aquarium (60l): 288527
# TV (50cm): 309076
# Water heater (200l): 2219048
# Microwave oven (1,65kW): 111127
# Site consumption (Garage, 200l): 5843982
# TV (72cm): 258050
# Microwave oven (2,75kW): 72724
# Aquarium (28?C, 400l): 786133
# Microwave oven (1,98kW): 23064
# TV (24cm): 22380
# TV (66cm): 59749

# %%
# Initialize the total flexibility sum
global_flexibility_sum = 0

# Sum up all the flexibility values across all devices
for total_sum in total_flexibility_per_device.values():
    global_flexibility_sum += total_sum

# Print the total flexibility sum
print("Total flexibility sum across all devices:", global_flexibility_sum)
# Out:
# Total flexibility sum across all devices: 181095941

# %% [markdown]
# ## not flexible sum

# %%
import pandas as pd

# Define the range of sheet names
start_sheet = 2000900
end_sheet = 2000997

# Initialize a dictionary to store the sum of each not flexible power for each sheet
not_flexible_sum_per_sheet = {}

# Iterate through each sheet in the specified range
for sheet_num in range(start_sheet, end_sheet + 1):
    sheet_name = str(sheet_num)
    try:
        # Read the sheet
        df = pd.read_excel("modified_combined_data_all_sheets_final.xlsx", sheet_name=sheet_name)

        # Extract flexibility information from the second row
        flexibility_row = df.iloc[0, 3:]

        # Identify not flexible devices based on the flexibility information
        not_flexible_devices = [col for col, flexibility in zip(df.columns[3:], flexibility_row) if flexibility.lower() != 'flexible']

        # Filter out the first two rows
        df_numeric = df.iloc[1:]

        # Calculate the sum of each not flexible power
        not_flexible_sum = df_numeric[not_flexible_devices].sum()

        # Store the sum of each not flexible power for the current sheet
        not_flexible_sum_per_sheet[sheet_name] = not_flexible_sum
    except Exception as e:
        print(f"Error processing sheet {sheet_name}: {e}")

# Print the sum of each not flexible power for each sheet
for sheet_name, not_flexible_sum in not_flexible_sum_per_sheet.items():
    print(f"Sheet {sheet_name}:")
    print(not_flexible_sum)
# Out:
# Sheet 2000900:
# Fridge (Kitchen, 180l)              262356
# Halogen lamp 1 (0,5kW)               97408
# Site consumption ()                5618893
# Total site light consumption ()     541887
# Vertical freezer (Cellar, 145l)     340305
# dtype: object
# Sheet 2000901:
# Chest freezer (Kitchen, 200l)       631926
# Fridge (Kitchen, 200l)              231467
# Non halogen lamp 1 ()                 1259
# Non halogen lamp 2 ()                36309
# Site consumption ()                4859623
# Total site light consumption ()     323613
# dtype: object
# Sheet 2000902:
# Fridge freezer (Kitchen, 203l/117l)     486990
# Halogen lamp 1 (0,5kW)                    1832
# Site consumption ()                    1929643
# Total site light consumption ()         130665
# dtype: object
# Sheet 2000903:
# Chest freezer (273l)     253991
# Halogen lamp 1 ()        166654
# Halogen lamp 2 ()         13723
# Halogen lamp 3 ()        102319
# Halogen lamp 4 ()         68376
# Site consumption ()     4584779
# dtype: object
# Sheet 2000904:
# Chest freezer (Garage, 200l)         480691
# Halogen lamp 1 ()                     10116
# Non halogen lamp 1 ()                 59488
# Non halogen lamp 2 ()                   224
# Site consumption ()                10467429
# Total site light consumption ()      862797
# dtype: object
# Sheet 2000905:
# Chest freezer (Storeroom, 191l)     671670
# Fridge freezer (172l/94l)           783531
# Halogen lamp 1 (0,5kW)               14755
# Site consumption ()                2739073
# Total site light consumption ()     203092
# dtype: object
# Sheet 2000906:
# Fridge freezer (267l/48l)           649274
# Non halogen lamp 1 (0,5kW)           50616
# Site consumption ()                3714951
# Total site light consumption ()     481599
# Vertical freezer (288l)             332873
# dtype: object
# Sheet 2000907:
# Site consumption ()                6864864
# Total site light consumption ()     700578
# dtype: object
# Sheet 2000908:
# Fridge freezer (Kitchen, 182l/48l)     496624
# Site consumption ()                   3531659
# Total site light consumption ()        220345
# Vertical freezer (Kitchen, 265l)       640308
# dtype: object
# Sheet 2000909:
# Electric heating (altogether) ()      1680899
# Fridge freezer (Kitchen, 221l/87l)     640506
# Halogen lamp 1 ()                        4258
# Site consumption ()                   9632654
# Total site light consumption ()        523511
# dtype: object
# Sheet 2000910:
# Fridge freezer (Kitchen, 190l/55l)     488493
# Halogen lamp 1 (0,5kW)                   6612
# Site consumption ()                   2340814
# Total site light consumption ()        120355
# Vertical freezer (Kitchen, 120l)       526690
# dtype: object
# Sheet 2000911:
# Fridge freezer (Kitchen, 217l/48l)     468131
# Non halogen lamp 1 ()                   28994
# Non halogen lamp 2 ()                      70
# Non halogen lamp 3 ()                    4404
# Non halogen lamp 4 ()                    1040
# Site consumption ()                   1776759
# Total site light consumption ()        172802
# dtype: object
# Sheet 2000912:
# Fridge freezer (Kitchen, 325l/75l)     904880
# Non halogen lamp 1 ()                  299088
# Non halogen lamp 2 ()                    7991
# Site consumption ()                   7815483
# Total site light consumption ()        841375
# Vertical freezer (Storeroom, 145l)     614593
# dtype: object
# Sheet 2000913:
# Fridge freezer (Kitchen, 195l/152l)     491044
# Halogen lamp 1 (0,5kW)                   69142
# Site consumption ()                    2774574
# Total site light consumption ()         160241
# dtype: object
# Sheet 2000914:
# Electric heating (altogether) ()       7586762
# Fridge (Kitchen, 300l)                  226264
# Halogen lamp 1 ()                        28986
# Site consumption ()                   13600342
# Total site light consumption ()         174630
# Vertical freezer (Storeroom, 280l)      569456
# dtype: object
# Sheet 2000915:
# Chest freezer (Garage, 440l)             643358
# Heat pump ()                            4810275
# Site consumption ()                    12387454
# Total site light consumption (36cm)      402852
# dtype: object
# Sheet 2000916:
# Chest freezer (Garage, 300l)        255413
# Site consumption ()                3299934
# Total site light consumption ()      82054
# dtype: object
# Sheet 2000917:
# Fridge (Kitchen, 310l)              370369
# Non halogen lamp 1 ()                 3814
# Non halogen lamp 2 ()                 8032
# Site consumption ()                3581917
# Total site light consumption ()     301017
# dtype: object
# Sheet 2000918:
# Fridge freezer (190l/50l)           350912
# Halogen lamp 1 (0,5kW)              107572
# Site consumption ()                1919105
# Total site light consumption ()     158297
# dtype: object
# Sheet 2000919:
# Fridge freezer (Kitchen, 206l)     350948
# Site consumption ()                780253
# Vertical freezer (Garage, 261l)     78087
# dtype: object
# Sheet 2000920:
# Fridge freezer (Kitchen, 350l)    403038
# Fridge (Kitchen, 350l)            413867
# Halogen lamp 1 (0,3kW)            403225
# Site consumption ()               409137
# Vertical freezer ()               402336
# dtype: object
# Sheet 2000921:
# Electric heating (altogether) ()        323511
# No-frost fridge (Kitchen, 225l/21l)     979782
# Site consumption ()                    8539991
# Total site light consumption ()         798827
# dtype: object
# Sheet 2000922:
# Fridge freezer (Kitchen, 347l/113l)     839946
# Site consumption ()                    3127514
# Total site light consumption ()         348009
# dtype: object
# Sheet 2000923:
# Fridge (Kitchen, 166l/17l)          260422
# Non halogen lamp 1 ()                  741
# Non halogen lamp 2 ()                80766
# Non halogen lamp 3 ()                20986
# Site consumption ()                2157395
# Total site light consumption ()     328651
# dtype: object
# Sheet 2000924:
# Halogen lamp 1 ()                  898579
# Site consumption ()                874424
# Total site light consumption ()    846955
# Vertical freezer (122l)            867960
# dtype: object
# Sheet 2000925:
# Chest freezer (Garage)              937502
# Fridge (Kitchen)                    280465
# Halogen lamp 1 (0,3kW)              342596
# Site consumption ()                3585835
# Total site light consumption ()     317608
# dtype: object
# Sheet 2000926:
# Chest freezer ()                    425477
# Fridge (Kitchen, 335l)              192970
# Fridge (Cellar, 65l)                476330
# Halogen lamp 1 ()                     6629
# Halogen lamp 2 ()                    40398
# Halogen lamp 3 ()                    49846
# Halogen lamp 4 ()                    41067
# Non halogen lamp 1 ()                 6629
# Site consumption ()                5203856
# Total site light consumption ()    1033938
# dtype: object
# Sheet 2000927:
# Fridge freezer (Kitchen, 245l)     430337
# Fridge (Boiler room)                    0
# Halogen lamp 1 (0,3kW)             124254
# Halogen lamp 2 (0,3kW)              51304
# Site consumption ()               4577075
# dtype: object
# Sheet 2000928:
# Chest freezer ()                     239365
# Electric heating (altogether) ()    5516240
# Fridge freezer ()                    320494
# Site consumption ()                 9611137
# Total site light consumption ()      185727
# dtype: object
# Sheet 2000929:
# Fridge freezer (Kitchen, 263l/92l)     468452
# Halogen lamp 1 (0,5kW)                 285841
# Site consumption ()                   2205184
# dtype: object
# Sheet 2000930:
# Fridge freezer (Kitchen, 276l/53l)     534415
# Site consumption ()                   6301242
# Vertical freezer (Garage)              428065
# dtype: object
# Sheet 2000931:
# Fridge freezer (Kitchen, 195l/40l)     514372
# Non halogen lamp 1 ()                     480
# Site consumption ()                   4230936
# Total site light consumption ()        249856
# Vertical freezer (Garage, 247l)        543832
# dtype: object
# Sheet 2000932:
# Fridge freezer (Kitchen, 310l/67l)     851976
# Non halogen lamp 1 ()                     605
# Non halogen lamp 2 ()                    2466
# Non halogen lamp 3 ()                    1908
# Site consumption ()                   2800415
# Total site light consumption ()        285813
# dtype: object
# Sheet 2000933:
# Fridge freezer (Kitchen, 180l/46l)    488262
# dtype: object
# Sheet 2000934:
# Electric heating (altogether) ()     4928249
# Halogen lamp 1 ()                       2000
# Site consumption ()                 12465930
# Total site light consumption ()      1010617
# Vertical freezer ()                   767310
# dtype: object
# Sheet 2000935:
# Fridge freezer (Kitchen, 270l/50l)     503434
# Non halogen lamp 1 ()                      68
# Non halogen lamp 2 ()                     891
# Non halogen lamp 3 ()                   23342
# Site consumption ()                   2553119
# Total site light consumption ()        301366
# dtype: object
# Sheet 2000936:
# Electric heating (altogether) ()      90754
# Fridge (Kitchen, 217l)               394457
# Site consumption ()                 5779434
# Total site light consumption ()      224173
# Vertical freezer (Garage, 125l)      328003
# dtype: object
# Sheet 2000937:
# Chest freezer (Cellar, 610l)    621339
# Halogen lamp 1 (0,5kW)           29589
# dtype: object
# Sheet 2000938:
# Chest freezer (Garage, 506l)         1062443
# Electric heating (altogether) ()     7874283
# Fridge (220l)                         319256
# Site consumption ()                 15153904
# Total site light consumption ()       253978
# dtype: object
# Sheet 2000939:
# Fridge freezer (Kitchen, 270l/50l)     469782
# Fridge (Garage, 140l)                  178251
# Halogen lamp 1 ()                       11608
# Site consumption ()                   4904597
# Vertical freezer (Garage, 335l)        813023
# dtype: object
# Sheet 2000940:
# Fridge freezer (Kitchen, 265l/67l)     458412
# Site consumption ()                   6783026
# Vertical freezer (Laundry, 265l)       418596
# dtype: object
# Sheet 2000941:
# Chest freezer (Kitchen)             809623
# Fridge (Kitchen)                    275235
# Fridge (Living room, 94l)           252838
# Site consumption ()                3113205
# Total site light consumption ()     190360
# dtype: object
# Sheet 2000942:
# Chest freezer (Garage, 350l)           337544
# Fridge freezer (Kitchen, 299l/67l)     608509
# Halogen lamp 1 (0,5kW)                 360199
# Site consumption ()                   3447447
# dtype: object
# Sheet 2000943:
# Fridge (Kitchen, 231l)              573013
# Fridge (Kitchen, 110l)              212082
# Halogen lamp 1 ()                     1001
# Site consumption ()                3903816
# Vertical freezer (Garage, 208l)     512838
# dtype: object
# Sheet 2000944:
# Electric heating (altogether) ()       7199664
# Fridge (Kitchen, 195l)                  240406
# Halogen lamp 1 (0,5kW)                   76296
# Site consumption ()                   13424730
# Total site light consumption ()        1762712
# Vertical freezer (Storeroom, 113l)      324293
# dtype: object
# Sheet 2000945:
# Chest freezer (540l)                  395952
# Electric heating (altogether) ()     3929852
# Fridge freezer (184l/96l)             575859
# Site consumption ()                 10219426
# Total site light consumption ()       572939
# dtype: object
# Sheet 2000946:
# Chest freezer (Garage, 264l)        447890
# Halogen lamp 1 ()                     6856
# Site consumption ()                2595695
# Total site light consumption ()     267579
# dtype: object
# Sheet 2000947:
# Fridge (386l)                  435846
# Site consumption ()           8585884
# Vertical freezer (Kitchen)     463154
# dtype: object
# Sheet 2000948:
# Fridge (230l)                        440039
# Fridge ()                             53279
# Halogen lamp 1 (0,5kW)               140264
# Heat pump ()                        3033135
# Site consumption ()                11460501
# Total site light consumption ()      139148
# Vertical freezer ()                  443128
# dtype: object
# Sheet 2000949:
# Fridge freezer (Kitchen, 292l/62l)       317522
# Halogen lamp 1 (0,3kW)                   102396
# Site consumption ()                     4148177
# Vertical freezer (Boiler room, 240l)     644720
# dtype: object
# Sheet 2000950:
# Fridge freezer ()        885633
# Site consumption ()    12324897
# dtype: object
# Sheet 2000951:
# Chest freezer (Storeroom, 213l)     338044
# Fridge (Kitchen, 227l)              466937
# Halogen lamp 1 ()                   300296
# Non halogen lamp 1 ()                13053
# Non halogen lamp 2 ()                  944
# Site consumption ()                6361052
# Total site light consumption ()     789582
# Vertical freezer (Garage, 296l)     426151
# dtype: object
# Sheet 2000952:
# Chest freezer (Garage, 400l)     485845
# Site consumption ()             5848728
# dtype: object
# Sheet 2000953:
# Chest freezer (Storeroom, 260l)         641090
# Electric heating (altogether) ()      11017759
# Fridge freezer (Kitchen, 222l/60l)      537921
# Non halogen lamp 1 ()                    96240
# Non halogen lamp 2 ()                        0
# Site consumption ()                   15770476
# Total site light consumption ()         174494
# dtype: object
# Sheet 2000954:
# Electric heating (altogether) ()      11250758
# Fridge (Storeroom, 301l)                304569
# Site consumption ()                   18560897
# Vertical freezer (Storeroom, 295l)      677011
# dtype: object
# Sheet 2000955:
# Fridge freezer (Kitchen, 184l/64l)     403090
# Site consumption ()                   6310241
# dtype: object
# Sheet 2000956:
# Fridge freezer (Kitchen, 186l/40l)     339536
# Non halogen lamp 1 ()                       0
# Non halogen lamp 2 ()                     714
# Site consumption ()                   3681117
# Total site light consumption ()         98406
# Vertical freezer (Kitchen, 211l)       376455
# dtype: object
# Sheet 2000957:
# Fridge freezer (Kitchen, 270l/66l)     852065
# Site consumption ()                   2588660
# dtype: object
# Sheet 2000958:
# Fridge freezer (Kitchen, 255l/75l)     618915
# Site consumption ()                   2042570
# dtype: object
# Sheet 2000959:
# Electric heating (altogether) ()     2422406
# Fridge freezer (Garage, 230l/45l)     404014
# Site consumption ()                  9115534
# Total site light consumption ()       126439
# dtype: object
# Sheet 2000960:
# Fridge freezer (Kitchen, 208l/116l)     450671
# Site consumption ( )                   4360537
# dtype: object
# Sheet 2000961:
# Fridge freezer (Kitchen, 200l/50l)     430547
# Halogen lamp 1 ()                      320258
# Non halogen lamp 1 ()                    2362
# Non halogen lamp 2 ()                    6108
# Non halogen lamp 3 ()                   28392
# Site consumption ()                   5628855
# Total site light consumption ()        290725
# dtype: object
# Sheet 2000962:
# Chest freezer (Cellar, 350l)        329105
# Fridge (Kitchen, 200l)              224184
# Halogen lamp 1 (0,5kW)              307220
# Site consumption ()                9248214
# Total site light consumption ()     529993
# dtype: object
# Sheet 2000963:
# Fridge freezer (Kitchen, 250l/66l)     800103
# Halogen lamp 1 (0,3kW)                 226012
# Halogen lamp 2 (0,5kW)                  36805
# Site consumption ()                   3249756
# dtype: object
# Sheet 2000964:
# Aquarium (28?C, 120l)                   417364
# Fridge freezer (Kitchen, 210l/120l)     916731
# Non halogen lamp 1 ()                      664
# Non halogen lamp 2 ()                        0
# Non halogen lamp 3 ()                     1232
# Non halogen lamp 4 ()                      368
# Site consumption ()                    5140577
# Total site light consumption ()        1345434
# dtype: object
# Sheet 2000965:
# Fridge freezer (Kitchen, 195l/150l)     760042
# Halogen lamp 1 (0,3kW)                  379805
# Site consumption ()                    5419509
# dtype: object
# Sheet 2000966:
# Chest freezer (Garage, 400l)           515836
# Fridge freezer (Kitchen, 430l/91l)     723199
# Halogen lamp 1 ()                        1577
# Site consumption ()                   4532889
# Total site light consumption ()        383082
# dtype: object
# Sheet 2000967:
# Electric heating (altogether) ()    5352833
# Fridge freezer (320l/85l)            407050
# Halogen lamp 1 ()                     84252
# Halogen lamp 2 ()                     15747
# Non halogen lamp 1 ()                  1245
# Site consumption ()                 9535895
# Total site light consumption ()      155732
# dtype: object
# Sheet 2000968:
# Electric heating (altogether) ()     941507
# Fridge (Kitchen, 140l)               195022
# Site consumption ()                 3238028
# dtype: object
# Sheet 2000969:
# Electric heating (altogether) ()    5141186
# Halogen lamp 1 ()                    107316
# Site consumption ()                 9668744
# dtype: object
# Sheet 2000970:
# Fridge freezer (Kitchen, 315l/60l)     410933
# Halogen lamp 1 ()                      128435
# Site consumption ()                   3701065
# Total site light consumption ()        509603
# dtype: object
# Sheet 2000971:
# Electric heating ()                    4169096
# Fridge freezer (Garage, 190l/120l)      399012
# Fridge freezer (Garage, 250l/50l)       593690
# Fridge (Kitchen, 140l)                  153838
# Fridge (Loft, 20l)                      567916
# Halogen lamp 1 (0,5kW)                  384163
# Halogen lamp 2 (0,5kW)                   29516
# Site consumption ()                   10686064
# dtype: object
# Sheet 2000972:
# Fridge freezer (Kitchen, 193l/121l)     478767
# Halogen lamp 1 ()                       129390
# Halogen lamp 2 ()                        67703
# Halogen lamp 3 ()                        39427
# Site consumption ()                    2868734
# dtype: object
# Sheet 2000973:
# Fridge (Kitchen)              187421
# Site consumption ()          3572525
# Vertical freezer (Cellar)    1107670
# dtype: object
# Sheet 2000974:
# Electric heating (altogether) ()        313236
# Fridge freezer (Kitchen, 233l/122l)     461924
# Halogen lamp 1 ()                        93533
# Halogen lamp 2 ()                        38240
# Halogen lamp 3 ()                        44145
# Halogen lamp 4 ()                        56315
# Site consumption ()                    7091696
# dtype: object
# Sheet 2000975:
# Electric heating (altogether) ()    2330680
# Fridge ()                            236785
# Halogen lamp 1 ()                        27
# Site consumption ()                 4611270
# Vertical freezer (50l)               457071
# dtype: object
# Sheet 2000976:
# Fridge freezer (Kitchen/67l)        754576
# Halogen lamp 1 ()                        0
# Halogen lamp 2 ()                      995
# Site consumption ()                3093032
# Total site light consumption ()     350227
# dtype: object
# Sheet 2000977:
# Electric heating ()       837147
# Electric heating ().1    1028095
# Electric heating ().2    1160026
# Fridge (389l)             353466
# Halogen lamp 1 ()          27865
# dtype: object
# Sheet 2000978:
# Electric heating (altogether) ()     146411
# Fridge freezer ()                    387160
# Halogen lamp 1 ()                      1436
# Halogen lamp 2 ()                       423
# Site consumption ()                 8454667
# Total site light consumption ()      192610
# dtype: object
# Sheet 2000979:
# Fridge freezer (Kitchen, 187l/48l)     483836
# Site consumption ()                   2923532
# dtype: object
# Sheet 2000980:
# Fridge freezer (Kitchen, 382l/86l)     601913
# Halogen lamp 1 ()                       69884
# Halogen lamp 2 ()                       85476
# Site consumption ()                   6322781
# Total site light consumption ()       2576923
# dtype: object
# Sheet 2000981:
# Chest freezer (Garage, 191l)        185013
# Fridge (Kitchen, 319l)              127650
# Site consumption ()                5200443
# Total site light consumption ()     374957
# dtype: object
# Sheet 2000982:
# Electric heating (altogether) ()       2781923
# Fridge freezer (Kitchen, 343l/121l)     556869
# Site consumption ()                    8440750
# Total site light consumption ()         590609
# dtype: object
# Sheet 2000983:
# Electric heating (altogether) ()     817597
# Fridge freezer (323l/71l)            432976
# Non halogen lamp 1 ()                   807
# Site consumption ()                 4228875
# Total site light consumption ()       15255
# dtype: object
# Sheet 2000984:
# Fridge freezer (Kitchen, 326l/90l)     567475
# Halogen lamp 1 ()                      154635
# Halogen lamp 2 ()                      206203
# Halogen lamp 3 ()                        9671
# Halogen lamp 4 ()                      226006
# Halogen lamp 5 ()                      245334
# Site consumption ()                   4124729
# Total site light consumption ()        183294
# dtype: object
# Sheet 2000985:
# Fridge freezer (Kitchen, 250l/54l)     671418
# Halogen lamp 1 ()                       20507
# Halogen lamp 2 ()                       11058
# Site consumption ()                   3315514
# Total site light consumption ()        477532
# dtype: object
# Sheet 2000986:
# Chest freezer (Kitchen, 182l)          259270
# Fridge freezer (Kitchen, 250l/60l)     561315
# Site consumption ()                   2302281
# dtype: object
# Sheet 2000987:
# Chest freezer (Garage, 400l)             520299
# Fridge freezer (Kitchen, 190l/120l)      203687
# Site consumption ()                    10103915
# dtype: object
# Sheet 2000988:
# Fridge (Kitchen, 200l)               225438
# Halogen lamp 1 (0,1kW)                31905
# Non halogen lamp 1 ()                  4905
# Non halogen lamp 2 ()                105698
# Non halogen lamp 3 ()                     0
# Site consumption ()                 3768261
# Total site light consumption ()      452804
# Vertical freezer (Kitchen, 247l)     397473
# dtype: object
# Sheet 2000989:
# Chest freezer (Garage, 175l)    927501
# dtype: object
# Sheet 2000990:
# Electric heating (altogether) ()    1384778
# Fridge (Kitchen, 236l)               223193
# Site consumption ()                 5516929
# Vertical freezer (Garage, 291l)      316535
# dtype: object
# Sheet 2000991:
# Chest freezer (Kitchen, 108l)     546011
# Site consumption ()              4684411
# dtype: object
# Sheet 2000992:
# Chest freezer (200l)       507318
# Fridge (Kitchen, 255l)     262681
# Site consumption ()       3376486
# dtype: object
# Sheet 2000993:
# Chest freezer (410l)                   79942
# Fridge freezer (Kitchen, 196l/52l)    147141
# Site consumption ()                   635496
# dtype: object
# Sheet 2000994:
# Fridge freezer (Kitchen, 192l/45l)     618899
# Site consumption ()                   1539807
# Vertical freezer (Kitchen, 210l)       430987
# dtype: object
# Sheet 2000995:
# Chest freezer (Garage, 405l)          1161875
# Fridge freezer (Kitchen, 187l/48l)     708016
# Non halogen lamp 1 ()                    1813
# Non halogen lamp 2 ()                     786
# Non halogen lamp 3 ()                    3600
# Site consumption ()                   4034832
# Total site light consumption ()        641355
# dtype: object
# Sheet 2000996:
# Chest freezer ()                       625583
# Electric deep frier ()                   5578
# Fridge freezer (Kitchen, 100l/30l)     649770
# Fridge (Veranda, 114l)                 171348
# Site consumption ()                   3939972
# dtype: object
# Sheet 2000997:
# Fridge freezer (Garage, 197l/53l)     591824
# Non halogen lamp 1 ()                  22398
# Site consumption ()                  4857439
# Total site light consumption ()       290061
# Vertical freezer (Garage, 213l)       640606
# dtype: object

# %%
# Convert the dictionary into a DataFrame
not_flexible_sum_df = pd.DataFrame(not_flexible_sum_per_sheet)

# Save the DataFrame to an Excel file
#not_flexible_sum_df.to_excel("not_flexible_sum_per_sheet.xlsx")

# %%
not_flexible_sum_df
# Out:
#                                    2000900 2000901 2000902 2000903 2000904  \
# Aquarium (28?C, 120l)                  NaN     NaN     NaN     NaN     NaN
# Chest freezer ()                       NaN     NaN     NaN     NaN     NaN
# Chest freezer (200l)                   NaN     NaN     NaN     NaN     NaN
# Chest freezer (273l)                   NaN     NaN     NaN  253991     NaN
# Chest freezer (410l)                   NaN     NaN     NaN     NaN     NaN
# ...                                    ...     ...     ...     ...     ...
# Vertical freezer (Laundry, 265l)       NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 113l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 145l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 280l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 295l)     NaN     NaN     NaN     NaN     NaN
#
#                                    2000905 2000906 2000907 2000908 2000909  \
# Aquarium (28?C, 120l)                  NaN     NaN     NaN     NaN     NaN
# Chest freezer ()                       NaN     NaN     NaN     NaN     NaN
# Chest freezer (200l)                   NaN     NaN     NaN     NaN     NaN
# Chest freezer (273l)                   NaN     NaN     NaN     NaN     NaN
# Chest freezer (410l)                   NaN     NaN     NaN     NaN     NaN
# ...                                    ...     ...     ...     ...     ...
# Vertical freezer (Laundry, 265l)       NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 113l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 145l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 280l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 295l)     NaN     NaN     NaN     NaN     NaN
#
#                                     ... 2000988 2000989 2000990 2000991  \
# Aquarium (28?C, 120l)               ...     NaN     NaN     NaN     NaN
# Chest freezer ()                    ...     NaN     NaN     NaN     NaN
# Chest freezer (200l)                ...     NaN     NaN     NaN     NaN
# Chest freezer (273l)                ...     NaN     NaN     NaN     NaN
# Chest freezer (410l)                ...     NaN     NaN     NaN     NaN
# ...                                 ...     ...     ...     ...     ...
# Vertical freezer (Laundry, 265l)    ...     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 113l)  ...     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 145l)  ...     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 280l)  ...     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 295l)  ...     NaN     NaN     NaN     NaN
#
#                                    2000992 2000993 2000994 2000995 2000996  \
# Aquarium (28?C, 120l)                  NaN     NaN     NaN     NaN     NaN
# Chest freezer ()                       NaN     NaN     NaN     NaN  625583
# Chest freezer (200l)                507318     NaN     NaN     NaN     NaN
# Chest freezer (273l)                   NaN     NaN     NaN     NaN     NaN
# Chest freezer (410l)                   NaN   79942     NaN     NaN     NaN
# ...                                    ...     ...     ...     ...     ...
# Vertical freezer (Laundry, 265l)       NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 113l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 145l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 280l)     NaN     NaN     NaN     NaN     NaN
# Vertical freezer (Storeroom, 295l)     NaN     NaN     NaN     NaN     NaN
#
#                                    2000997
# Aquarium (28?C, 120l)                  NaN
# Chest freezer ()                       NaN
# Chest freezer (200l)                   NaN
# Chest freezer (273l)                   NaN
# Chest freezer (410l)                   NaN
# ...                                    ...
# Vertical freezer (Laundry, 265l)       NaN
# Vertical freezer (Storeroom, 113l)     NaN
# Vertical freezer (Storeroom, 145l)     NaN
# Vertical freezer (Storeroom, 280l)     NaN
# Vertical freezer (Storeroom, 295l)     NaN
#
# [164 rows x 98 columns]

# %%
# Initialize a dictionary to store the sum of each device across all sheets
total_not_flexibility_per_device = {}

# Iterate through each sheet
for not_flexible_sum in not_flexible_sum_per_sheet.values():
    # Iterate through each device in the current sheet
    for device, value in not_flexible_sum.items():
        # Add the value to the total for the current device
        total_not_flexibility_per_device[device] = total_not_flexibility_per_device.get(device, 0) + value

# Print the sum of flexibility for each device across all sheets
print("Total flexibility sum for each device:")
for device, total_sum in total_not_flexibility_per_device.items():
    print(f"{device}: {total_sum}")
# Out:
# Total flexibility sum for each device:
# Fridge (Kitchen, 180l): 262356
# Halogen lamp 1 (0,5kW): 1880893
# Site consumption (): 528045380
# Total site light consumption (): 25666231
# Vertical freezer (Cellar, 145l): 340305
# Chest freezer (Kitchen, 200l): 631926
# Fridge (Kitchen, 200l): 681089
# Non halogen lamp 1 (): 544653
# Non halogen lamp 2 (): 250999
# Fridge freezer (Kitchen, 203l/117l): 486990
# Chest freezer (273l): 253991
# Halogen lamp 1 (): 2576098
# Halogen lamp 2 (): 479966
# Halogen lamp 3 (): 245408
# Halogen lamp 4 (): 391764
# Chest freezer (Garage, 200l): 480691
# Chest freezer (Storeroom, 191l): 671670
# Fridge freezer (172l/94l): 783531
# Fridge freezer (267l/48l): 649274
# Non halogen lamp 1 (0,5kW): 50616
# Vertical freezer (288l): 332873
# Fridge freezer (Kitchen, 182l/48l): 496624
# Vertical freezer (Kitchen, 265l): 640308
# Electric heating (altogether) (): 83031288
# Fridge freezer (Kitchen, 221l/87l): 640506
# Fridge freezer (Kitchen, 190l/55l): 488493
# Vertical freezer (Kitchen, 120l): 526690
# Fridge freezer (Kitchen, 217l/48l): 468131
# Non halogen lamp 3 (): 83864
# Non halogen lamp 4 (): 1408
# Fridge freezer (Kitchen, 325l/75l): 904880
# Vertical freezer (Storeroom, 145l): 614593
# Fridge freezer (Kitchen, 195l/152l): 491044
# Fridge (Kitchen, 300l): 226264
# Vertical freezer (Storeroom, 280l): 569456
# Chest freezer (Garage, 440l): 643358
# Heat pump (): 7843410
# Total site light consumption (36cm): 402852
# Chest freezer (Garage, 300l): 255413
# Fridge (Kitchen, 310l): 370369
# Fridge freezer (190l/50l): 350912
# Fridge freezer (Kitchen, 206l): 350948
# Vertical freezer (Garage, 261l): 78087
# Fridge freezer (Kitchen, 350l): 403038
# Fridge (Kitchen, 350l): 413867
# Halogen lamp 1 (0,3kW): 1578288
# Vertical freezer (): 1612774
# No-frost fridge (Kitchen, 225l/21l): 979782
# Fridge freezer (Kitchen, 347l/113l): 839946
# Fridge (Kitchen, 166l/17l): 260422
# Vertical freezer (122l): 867960
# Chest freezer (Garage): 937502
# Fridge (Kitchen): 743121
# Chest freezer (): 1290425
# Fridge (Kitchen, 335l): 192970
# Fridge (Cellar, 65l): 476330
# Fridge freezer (Kitchen, 245l): 430337
# Fridge (Boiler room): 0
# Halogen lamp 2 (0,3kW): 51304
# Fridge freezer (): 1593287
# Fridge freezer (Kitchen, 263l/92l): 468452
# Fridge freezer (Kitchen, 276l/53l): 534415
# Vertical freezer (Garage): 428065
# Fridge freezer (Kitchen, 195l/40l): 514372
# Vertical freezer (Garage, 247l): 543832
# Fridge freezer (Kitchen, 310l/67l): 851976
# Fridge freezer (Kitchen, 180l/46l): 488262
# Fridge freezer (Kitchen, 270l/50l): 973216
# Fridge (Kitchen, 217l): 394457
# Vertical freezer (Garage, 125l): 328003
# Chest freezer (Cellar, 610l): 621339
# Chest freezer (Garage, 506l): 1062443
# Fridge (220l): 319256
# Fridge (Garage, 140l): 178251
# Vertical freezer (Garage, 335l): 813023
# Fridge freezer (Kitchen, 265l/67l): 458412
# Vertical freezer (Laundry, 265l): 418596
# Chest freezer (Kitchen): 809623
# Fridge (Living room, 94l): 252838
# Chest freezer (Garage, 350l): 337544
# Fridge freezer (Kitchen, 299l/67l): 608509
# Fridge (Kitchen, 231l): 573013
# Fridge (Kitchen, 110l): 212082
# Vertical freezer (Garage, 208l): 512838
# Fridge (Kitchen, 195l): 240406
# Vertical freezer (Storeroom, 113l): 324293
# Chest freezer (540l): 395952
# Fridge freezer (184l/96l): 575859
# Chest freezer (Garage, 264l): 447890
# Fridge (386l): 435846
# Vertical freezer (Kitchen): 463154
# Fridge (230l): 440039
# Fridge (): 290064
# Fridge freezer (Kitchen, 292l/62l): 317522
# Vertical freezer (Boiler room, 240l): 644720
# Chest freezer (Storeroom, 213l): 338044
# Fridge (Kitchen, 227l): 466937
# Vertical freezer (Garage, 296l): 426151
# Chest freezer (Garage, 400l): 1521980
# Chest freezer (Storeroom, 260l): 641090
# Fridge freezer (Kitchen, 222l/60l): 537921
# Fridge (Storeroom, 301l): 304569
# Vertical freezer (Storeroom, 295l): 677011
# Fridge freezer (Kitchen, 184l/64l): 403090
# Fridge freezer (Kitchen, 186l/40l): 339536
# Vertical freezer (Kitchen, 211l): 376455
# Fridge freezer (Kitchen, 270l/66l): 852065
# Fridge freezer (Kitchen, 255l/75l): 618915
# Fridge freezer (Garage, 230l/45l): 404014
# Fridge freezer (Kitchen, 208l/116l): 450671
# Site consumption ( ): 4360537
# Fridge freezer (Kitchen, 200l/50l): 430547
# Chest freezer (Cellar, 350l): 329105
# Fridge freezer (Kitchen, 250l/66l): 800103
# Halogen lamp 2 (0,5kW): 66321
# Aquarium (28?C, 120l): 417364
# Fridge freezer (Kitchen, 210l/120l): 916731
# Fridge freezer (Kitchen, 195l/150l): 760042
# Fridge freezer (Kitchen, 430l/91l): 723199
# Fridge freezer (320l/85l): 407050
# Fridge (Kitchen, 140l): 348860
# Fridge freezer (Kitchen, 315l/60l): 410933
# Electric heating (): 5006243
# Fridge freezer (Garage, 190l/120l): 399012
# Fridge freezer (Garage, 250l/50l): 593690
# Fridge (Loft, 20l): 567916
# Fridge freezer (Kitchen, 193l/121l): 478767
# Vertical freezer (Cellar): 1107670
# Fridge freezer (Kitchen, 233l/122l): 461924
# Vertical freezer (50l): 457071
# Fridge freezer (Kitchen/67l): 754576
# Electric heating ().1: 1028095
# Electric heating ().2: 1160026
# Fridge (389l): 353466
# Fridge freezer (Kitchen, 187l/48l): 1191852
# Fridge freezer (Kitchen, 382l/86l): 601913
# Chest freezer (Garage, 191l): 185013
# Fridge (Kitchen, 319l): 127650
# Fridge freezer (Kitchen, 343l/121l): 556869
# Fridge freezer (323l/71l): 432976
# Fridge freezer (Kitchen, 326l/90l): 567475
# Halogen lamp 5 (): 245334
# Fridge freezer (Kitchen, 250l/54l): 671418
# Chest freezer (Kitchen, 182l): 259270
# Fridge freezer (Kitchen, 250l/60l): 561315
# Fridge freezer (Kitchen, 190l/120l): 203687
# Halogen lamp 1 (0,1kW): 31905
# Vertical freezer (Kitchen, 247l): 397473
# Chest freezer (Garage, 175l): 927501
# Fridge (Kitchen, 236l): 223193
# Vertical freezer (Garage, 291l): 316535
# Chest freezer (Kitchen, 108l): 546011
# Chest freezer (200l): 507318
# Fridge (Kitchen, 255l): 262681
# Chest freezer (410l): 79942
# Fridge freezer (Kitchen, 196l/52l): 147141
# Fridge freezer (Kitchen, 192l/45l): 618899
# Vertical freezer (Kitchen, 210l): 430987
# Chest freezer (Garage, 405l): 1161875
# Electric deep frier (): 5578
# Fridge freezer (Kitchen, 100l/30l): 649770
# Fridge (Veranda, 114l): 171348
# Fridge freezer (Garage, 197l/53l): 591824
# Vertical freezer (Garage, 213l): 640606

# %%
# Initialize the total flexibility sum
global_not_flexibility_sum = 0

# Sum up all the flexibility values across all devices
for total_sum in total_not_flexibility_per_device.values():
    global_not_flexibility_sum += total_sum

# Print the total flexibility sum
print("Total flexibility sum across all devices:", global_not_flexibility_sum)
# Out:
# Total flexibility sum across all devices: 739148573

# %% [markdown]
# ## Indicators calculation

# %%
global_flexibility_sum/(global_flexibility_sum+global_not_flexibility_sum)
# Out:
# 0.1967911117588037
